# %%
import pandas as pd
import numpy as np
df=pd.read_excel("../data/数据整合cleaned去除异常值.xlsx")
# 查看数据概况
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   日期                       483 non-null    datetime64[ns]
#  1   机组                       483 non-null    object
#  2   负荷                       483 non-null    float64
#  3   再热汽温                     483 non-null    float64
#  4   氧量                       483 non-null    float64
#  5   排烟温度                     483 non-null    float64
#  6   送风机入口温度                  483 non-null    float64
#  7   主汽压                      483 non-null    float64
#  8   主汽温                      483 non-null    float64
#  9   排汽温度                     483 non-null    float64
#  10  给水温度                     483 non-null    float64
#  11  全水                       483 non-null    float64
#  12  Aar(%)收到基灰分              483 non-null    float64
#  13  Var(%)收到基挥发分             483 non-null    float64
#  14  Fcad(%)空干基固定碳            483 non-null    float64
#  15  QnetarMJ(MJ/kg)收到基低位发热量  483 non-null    float64
#  16  用电率                      483 non-null    float64
#  17  负荷率                      483 non-null    float64
#  18  碳排放强度                    483 non-null    float64
# dtypes: datetime64[ns](1), float64(17), object(1)
# memory usage: 71.8+ KB
#                                   日期          负荷        再热汽温          氧量  \
# count                            483  483.000000  483.000000  483.000000
# mean   2024-06-29 18:14:09.689441024  231.681642  558.511469    3.246129
# min              2024-01-01 00:00:00  168.195960  543.303483    2.151864
# 25%              2024-04-12 12:00:00  209.592747  555.145063    2.985687
# 50%              2024-07-01 00:00:00  232.741908  558.613689    3.188575
# 75%              2024-09-07 00:00:00  251.199590  562.478211    3.457846
# max              2024-12-29 00:00:00  318.628614  567.797029    4.587281
# std                              NaN   29.014496    5.090132    0.414119
#
#              排烟温度     送风机入口温度         主汽压         主汽温        排汽温度        给水温度  \
# count  483.000000  483.000000  483.000000  483.000000  483.000000  483.000000
# mean   122.319544   20.416379   19.957383  565.661395   54.603574  263.116860
# min    120.623286   -2.462930   15.853714  434.247253  -59.119384  181.856538
# 25%    122.104543   11.536680   18.754779  564.626238   32.324470  259.435135
# 50%    122.405643   22.135320   19.983088  565.958507   38.550136  263.601965
# 75%    122.635900   29.295636   21.057572  568.283287   49.275361  267.810972
# max    123.265218   73.678503   24.067829  570.469986  303.960967  278.553538
# std      0.461298   10.789415    1.641142    8.017311   43.856828    7.713805
#
#                全水  Aar(%)收到基灰分  Var(%)收到基挥发分  Fcad(%)空干基固定碳  \
# count  483.000000   483.000000    483.000000     483.000000
# mean     8.718375    30.545914     23.708746      39.529161
# min      4.375000    22.385000     21.150000      33.695000
# 25%      7.800000    28.476250     23.266250      38.280000
# 50%      8.775000    30.710000     23.715000      39.577500
# 75%      9.662500    32.373750     24.163750      40.913750
# max     13.900000    37.862500     25.845000      45.655000
# std      1.471225     2.658328      0.711236       1.799052
#
#        QnetarMJ(MJ/kg)收到基低位发热量         用电率         负荷率        碳排放强度
# count               483.000000  483.000000  483.000000   483.000000
# mean                 18.615700    6.480884   67.636005  4304.983739
# min                  16.440000    4.527000   49.821215  3117.475413
# 25%                  18.045000    6.003500   61.646910  3858.658495
# 50%                  18.570000    6.496000   67.681389  4387.213829
# 75%                  19.118750    7.019500   73.669219  4633.106537
# max                  20.837500    8.228000   92.486944  5248.528271
# std                   0.757847    0.728567    8.490979   441.516211

# %%
correlation_matrix = df.iloc[:, 2:].corr()#除日期、机组列

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 设置中文字体为 SimHei（黑体）
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体 SimHei
plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示问题

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
# 按特定特征的相关性进行排序，例如按第一列的相关性
target_feature = '碳排放强度'  # 将此替换为你要排序的特征名
# 获取该特征与其他特征的相关系数，按绝对值排序
sorted_correlations = correlation_matrix[target_feature].abs().sort_values(ascending=False)
# 打印排序后的结果
print(sorted_correlations)
# Out:
# 碳排放强度                      1.000000
# 用电率                        0.644561
# 再热汽温                       0.575939
# 排汽温度                       0.493487
# 负荷率                        0.436701
# 负荷                         0.422540
# 送风机入口温度                    0.348302
# 主汽压                        0.291695
# 排烟温度                       0.162223
# 主汽温                        0.158243
# 全水                         0.145743
# 给水温度                       0.132385
# 氧量                         0.102476
# QnetarMJ(MJ/kg)收到基低位发热量    0.083366
# Var(%)收到基挥发分               0.057668
# Aar(%)收到基灰分                0.031614
# Fcad(%)空干基固定碳              0.015559
# Name: 碳排放强度, dtype: float64
