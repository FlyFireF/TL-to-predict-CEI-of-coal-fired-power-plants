# %%
import pandas as pd
df_1_operation = pd.read_excel("../data/马鞍山1号电厂运行数据.xlsx")
df_1_operation
# Out:
#             时间        平均负荷     厂用电率       主汽压力        主汽温度        再热汽温  \
# 0   2023-08-01         NaN      NaN  16.065449         NaN         NaN
# 1   2023-08-02         NaN      NaN  17.535095         NaN         NaN
# 2   2023-08-03         NaN      NaN  17.535095         NaN         NaN
# 3   2023-08-04  463.799990      NaN  17.535095         NaN         NaN
# 4   2023-08-05  463.799990      NaN  17.535095         NaN         NaN
# ..         ...         ...      ...        ...         ...         ...
# 484 2024-12-27  536.785727  3.51448  23.833649  568.796295  565.480041
# 485 2024-12-28  388.962175  3.51448  18.112924  560.746643  547.274780
# 486 2024-12-29  435.360017  3.51448  18.704281  561.251831  556.695557
# 487 2024-12-30  363.211545  3.51448  16.992607  558.918640  545.457459
# 488 2024-12-31  474.793557  3.51448  20.548363  564.053528  560.266113
#
#            给水温度        真空度       排汽温度        排烟温度      进风温度     烟气含氧量  \
# ...

# %%
df_1_fuel = pd.read_excel("../data/马鞍山1号煤质.xlsx")
df_1_fuel = df_1_fuel.rename(columns={"日期":"时间"})
df_1_fuel
# Out:
#             时间  全水分%    水分%    灰份%  挥发份%Vad  挥发份%Vdaf  全硫%ar  全硫%ad   高位热量  \
# 0   2023-08-01  11.5   3.34  30.90    26.17     39.80   0.83   0.90  21.19
# 1   2023-08-02  12.3   3.81  29.05    26.37     39.30   0.69   0.76  21.47
# 2   2023-08-03  14.5   5.16  23.51    27.35     38.34   0.59   0.66  22.80
# 3   2023-08-04  14.3   5.66  24.20    27.91     39.80   0.64   0.71  21.95
# 4   2023-08-05  18.0   9.81  20.30    27.56     39.43   0.66   0.72  21.85
# ..         ...   ...    ...    ...      ...       ...    ...    ...    ...
# 514 2024-12-27  16.6   5.98  23.49    28.90     40.92   0.57   0.65  22.48
# 515 2024-12-28  20.0   9.44  19.40    30.64     43.09   0.69   0.79  21.95
# 516 2024-12-29  20.9   9.08  18.91    30.88     42.91   0.75   0.86  22.19
# 517 2024-12-30  19.5  10.12  20.41    29.88     43.01   0.74   0.82  21.59
# 518 2024-12-31  14.8   7.34  21.08    28.72     40.11   0.67   0.73  22.56
#
#       低位热量   固定碳%  #1煤量   #1热值     飞灰%#1 炉渣%#1
# ...

# %%
df_1_emission = pd.read_excel("../data/马鞍山1号碳排放.xlsx")
df_1_emission
# Out:
#             时间       碳排放强度
# 0   2023-08-01  874.946294
# 1   2023-08-02  860.640267
# 2   2023-08-03  880.361819
# 3   2023-08-04  857.798288
# 4   2023-08-05  853.045939
# ..         ...         ...
# 416 2024-12-27  794.480431
# 417 2024-12-28  795.348729
# 418 2024-12-29  896.680537
# 419 2024-12-30  897.858448
# 420 2024-12-31  823.233935
#
# [421 rows x 2 columns]

# %%
import functools as ft
df_merged = ft.reduce(lambda  left,right: pd.merge(left,right,on=['时间'],
                                            how='outer'), data_frames)#.fillna(0)
df_merged
# Out:
#             时间        平均负荷     厂用电率       主汽压力        主汽温度        再热汽温  \
# 0   2023-08-01         NaN      NaN  16.065449         NaN         NaN
# 1   2023-08-02         NaN      NaN  17.535095         NaN         NaN
# 2   2023-08-03         NaN      NaN  17.535095         NaN         NaN
# 3   2023-08-04  463.799990      NaN  17.535095         NaN         NaN
# 4   2023-08-05  463.799990      NaN  17.535095         NaN         NaN
# ..         ...         ...      ...        ...         ...         ...
# 514 2024-12-27  536.785727  3.51448  23.833649  568.796295  565.480041
# 515 2024-12-28  388.962175  3.51448  18.112924  560.746643  547.274780
# 516 2024-12-29  435.360017  3.51448  18.704281  561.251831  556.695557
# 517 2024-12-30  363.211545  3.51448  16.992607  558.918640  545.457459
# 518 2024-12-31  474.793557  3.51448  20.548363  564.053528  560.266113
#
#            给水温度        真空度       排汽温度        排烟温度  ...  全硫%ar  全硫%ad   高位热量  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 30 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   时间        519 non-null    datetime64[ns]
#  1   平均负荷      486 non-null    float64
#  2   厂用电率      474 non-null    float64
#  3   主汽压力      489 non-null    float64
#  4   主汽温度      474 non-null    float64
#  5   再热汽温      474 non-null    float64
#  6   给水温度      489 non-null    float64
#  7   真空度       489 non-null    float64
#  8   排汽温度      489 non-null    float64
#  9   排烟温度      489 non-null    float64
#  10  进风温度      474 non-null    float64
#  11  烟气含氧量     489 non-null    float64
#  12  运行小时      460 non-null    float64
#  13  发电煤耗      485 non-null    float64
#  14  负荷率       486 non-null    float64
#  15  全水分%      519 non-null    float64
#  16  水分%       519 non-null    float64
#  17  灰份%       519 non-null    float64
#  18  挥发份%Vad   519 non-null    float64
# ...

# %%
df_merged.replace('/', np.nan, inplace=True)
df_merged['飞灰%#1'] = pd.to_numeric(df_merged['飞灰%#1'], errors='coerce')
df_merged['炉渣%#1'] = pd.to_numeric(df_merged['炉渣%#1'], errors='coerce')

# %%
df_merged
# Out:
#             时间        平均负荷     厂用电率       主汽压力        主汽温度        再热汽温  \
# 0   2023-08-01         NaN      NaN  16.065449         NaN         NaN
# 1   2023-08-02         NaN      NaN  17.535095         NaN         NaN
# 2   2023-08-03         NaN      NaN  17.535095         NaN         NaN
# 3   2023-08-04  463.799990      NaN  17.535095         NaN         NaN
# 4   2023-08-05  463.799990      NaN  17.535095         NaN         NaN
# ..         ...         ...      ...        ...         ...         ...
# 514 2024-12-27  536.785727  3.51448  23.833649  568.796295  565.480041
# 515 2024-12-28  388.962175  3.51448  18.112924  560.746643  547.274780
# 516 2024-12-29  435.360017  3.51448  18.704281  561.251831  556.695557
# 517 2024-12-30  363.211545  3.51448  16.992607  558.918640  545.457459
# 518 2024-12-31  474.793557  3.51448  20.548363  564.053528  560.266113
#
#            给水温度        真空度       排汽温度        排烟温度  ...  全硫%ar  全硫%ad   高位热量  \
# ...

# %%
df_merged.to_excel("../data/马鞍山1号数据整合.xlsx")
